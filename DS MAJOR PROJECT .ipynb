# %%
import pandas as pd
df=pd.read_csv('heart_failure_clinical_records_dataset.csv')
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
df.shape
# Out:
# (299, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
df.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
#What is the average age in the dataset?
df['age'].mean()
# Out:
# 60.83389297658862

# %%
#How many patients are having high blood pressure?
df['high_blood_pressure'].value_counts()
# Out:
# high_blood_pressure
# 0    194
# 1    105
# Name: count, dtype: int64

# %%
#How many male and female patients? #1-male 0=Female
df['sex'].value_counts()
# Out:
# sex
# 1    194
# 0    105
# Name: count, dtype: int64

# %%
#Find the average ejection fraction	?
df['ejection_fraction'].mean()
# Out:
# 38.08361204013378

# %%
#what is the Death Event count?
df['DEATH_EVENT'].value_counts()
# Out:
# DEATH_EVENT
# 0    203
# 1     96
# Name: count, dtype: int64

# %%
#which age group has the highest death event?
df.groupby(by='age')['DEATH_EVENT'].max().sort_values(ascending=False)
# Out:
# age
# 62.000    1
# 75.000    1
# 60.667    1
# 65.000    1
# 68.000    1
# 69.000    1
# 70.000    1
# 72.000    1
# 73.000    1
# 77.000    1
# 59.000    1
# 80.000    1
# 82.000    1
# 85.000    1
# 86.000    1
# 87.000    1
# 90.000    1
# 94.000    1
# 60.000    1
# 95.000    1
# 58.000    1
# 54.000    1
# 42.000    1
# 45.000    1
# 46.000    1
# 48.000    1
# 49.000    1
# 50.000    1
# 57.000    1
# 53.000    1
# 51.000    1
# 55.000    1
# 52.000    0
# 67.000    0
# 66.000    0
# 56.000    0
# 78.000    0
# 79.000    0
# 64.000    0
# 81.000    0
# 47.000    0
# 63.000    0
# 41.000    0
# 44.000    0
# 43.000    0
# 61.000    0
# 40.000    0
# Name: DEATH_EVENT, dtype: int64

# %%
#How many  patients with diabetes?
df['diabetes'].value_counts()
# Out:
# diabetes
# 0    174
# 1    125
# Name: count, dtype: int64

# %%
#What is the average platelets?
df['platelets'].mean()
# Out:
# 263358.02926421404

# %%
#statics platelets.
df['platelets'].describe()
# Out:
# count       299.000000
# mean     263358.029264
# std       97804.236869
# min       25100.000000
# 25%      212500.000000
# 50%      262000.000000
# 75%      303500.000000
# max      850000.000000
# Name: platelets, dtype: float64

# %%
#age with highest platelets
df.groupby(by=df['age'])['platelets'].max().sort_values().index[0]
# Out:
# 47.0

# %%
df['DEATH_EVENT'].value_counts(0)
# Out:
# DEATH_EVENT
# 0    203
# 1     96
# Name: count, dtype: int64

# %%
#What is the distribution of age among patients with heart failure?
pd.unique(df['age'])
df['age'].value_counts()
# Out:
# age
# 60.000    33
# 50.000    27
# 65.000    26
# 70.000    25
# 45.000    19
# 55.000    17
# 75.000    11
# 53.000    10
# 58.000    10
# 63.000     8
# 80.000     7
# 72.000     7
# 40.000     7
# 42.000     7
# 85.000     6
# 68.000     5
# 52.000     5
# 62.000     5
# 51.000     4
# 59.000     4
# 61.000     4
# 73.000     4
# 49.000     4
# 69.000     3
# 46.000     3
# 64.000     3
# 82.000     3
# 90.000     3
# 78.000     2
# 60.667     2
# 54.000     2
# 77.000     2
# 57.000     2
# 66.000     2
# 44.000     2
# 67.000     2
# 95.000     2
# 48.000     2
# 43.000     1
# 86.000     1
# 81.000     1
# 79.000     1
# 41.000     1
# 94.000     1
# 87.000     1
# 47.000     1
# 56.000     1
# Name: count, dtype: int64

# %%
#What is the distribution of serum creatinine levels?
pd.unique(df['serum_creatinine'])
df['serum_creatinine'].value_counts()
# Out:
# serum_creatinine
# 1.00    50
# 1.10    32
# 0.90    32
# 1.20    24
# 0.80    24
# 1.30    20
# 0.70    19
# 1.18    11
# 1.40     9
# 1.70     9
# 1.83     8
# 1.60     6
# 1.90     5
# 2.10     5
# 1.50     5
# 0.60     4
# 1.80     4
# 2.30     3
# 2.70     3
# 2.50     3
# 3.50     2
# 2.40     2
# 3.00     2
# 0.50     1
# 5.00     1
# 0.75     1
# 6.10     1
# 3.40     1
# 3.70     1
# 9.00     1
# 4.00     1
# 3.20     1
# 5.80     1
# 2.90     1
# 2.00     1
# 2.20     1
# 6.80     1
# 9.40     1
# 4.40     1
# 3.80     1
# Name: count, dtype: int64

# %%
#patients age with creatinine phosphokinase
df.groupby(by=['age'])['creatinine_phosphokinase'].max().sort_values(ascending=False)
# Out:
# age
# 55.000    7861
# 45.000    7702
# 85.000    5882
# 42.000    5209
# 81.000    4540
# 52.000    3966
# 60.000    3964
# 70.000    2695
# 50.000    2522
# 53.000    1808
# 63.000    1767
# 65.000    1688
# 64.000    1610
# 69.000    1419
# 51.000    1380
# 73.000    1185
# 68.000    1021
# 49.000     972
# 72.000     943
# 80.000     898
# 82.000     855
# 46.000     719
# 75.000     675
# 62.000     655
# 40.000     624
# 47.000     582
# 94.000     582
# 67.000     582
# 58.000     582
# 86.000     582
# 54.000     582
# 61.000     582
# 44.000     582
# 48.000     582
# 77.000     418
# 95.000     371
# 43.000     358
# 90.000     337
# 59.000     280
# 78.000     224
# 60.667     151
# 87.000     149
# 41.000     148
# 56.000     135
# 57.000     129
# 66.000      72
# 79.000      55
# Name: creatinine_phosphokinase, dtype: int64

# %%
#correlation between creatinine_phosphokinase and platelets
df['creatinine_phosphokinase'].corr(df['platelets'])
# Out:
# 0.024463388519574105

# %%
#correlation between serum_creatinine and serum_sodium
df['serum_creatinine'].corr(df['serum_sodium'])
# Out:
# -0.1890952100911741

# %%
#Create a histogram of patient ages.
import matplotlib.pyplot as plt
import seaborn as sns
sns.histplot(df['age'],kde=True)
plt.title("Age of the Patients")
plt.show()

# %%
#Visualize the relationship between ejection fraction and serum creatinine levels.
sns.lineplot(x=df['ejection_fraction'],y=df['serum_creatinine'])
plt.show()

# %%
sns.boxplot(df['age'])
plt.show()

# %%
sns.pairplot(df,hue='age')
plt.title("Pair Plot of the Heart Failure Dataset")
plt.show()

# %%
# How does the distribution of Death event look in the dataset?
plt.bar(df['age'],df['DEATH_EVENT'])
plt.show()

# %%
#Importing Model
from sklearn.linear_model import LogisticRegression #Binary Label

# %%
#Importing accuracy score function
from sklearn.metrics import accuracy_score

# %%
#INput Feature (All the column except the label column)- x
#Target column (Label Column)- y
X= df.drop(columns='DEATH_EVENT',axis=1)
Y=df['DEATH_EVENT']

# %%
#Splitting the data into training data and testing data
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2)
#Model Training
model = LogisticRegression()
#Training the ML model with training data
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
#Model Evaluation
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(Y_train, X_train_prediction)
print("Accuracy score for the training data", training_data_accuracy)
# Out:
# Accuracy score for the training data 0.8200836820083682

# %%
#Model Evaluation
X_test_prediction = model.predict(X_test)
testing_data_accuracy = accuracy_score(Y_test, X_test_prediction)
print("Accuracy score for the testing data", testing_data_accuracy)
# Out:
# Accuracy score for the testing data 0.8666666666666667

# %%
#Prediction of one data point
prediction=model.predict(input_data_reshape)
if prediction == 0:
  print("The Patient will Alive")
else:
  print("The Patient ")
